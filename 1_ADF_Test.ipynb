# %% [markdown]
# <a href="https://colab.research.google.com/github/rajdas2001/Time-Series-Analysis/blob/main/1_ADF_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.machinelearningplus.com/time-series/augmented-dickey-fuller-test/

# %%
from statsmodels.tsa.stattools import adfuller
import pandas as pd
import numpy as np
# %matplotlib inline

url = 'https://raw.githubusercontent.com/selva86/datasets/master/a10.csv'
df = pd.read_csv(url, parse_dates=['date'], index_col='date')
series = df.loc[:, 'value'].values
df.plot(figsize=(14,8), legend=None, title='a10 - Drug Sales Series');

# %%
result = adfuller(series, autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for key, value in result[4].items():
    print('Critial Values:')
    print(f'   {key}, {value}')
# Out:
# ADF Statistic: 3.1451856893067287
# n_lags: 1.0
# p-value: 1.0
# Critial Values:
#    1%, -3.465620397124192
# Critial Values:
#    5%, -2.8770397560752436
# Critial Values:
#    10%, -2.5750324547306476

# %% [markdown]
# The p-value is obtained is greater than significance level of 0.05 and the ADF statistic is higher than any of the critical values.
#
# Clearly, there is no reason to reject the null hypothesis. So, the time series is in fact non-stationary.

# %%
series2 = np.random.randn(100)
result2 = adfuller(series2, autolag='AIC')
print(f'ADF Statistic: {result2[0]}')
print(f'p-value: {result2[1]}')
for key, value in result2[4].items():
    print('Critial Values:')
    print(f'   {key}, {value}')
# Out:
# ADF Statistic: -8.347512869876885
# p-value: 3.057023825857961e-13
# Critial Values:
#    1%, -3.498198082189098
# Critial Values:
#    5%, -2.891208211860468
# Critial Values:
#    10%, -2.5825959973472097

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig, axes = plt.subplots(figsize=(10,7))
plt.plot(series2);
plt.title('Random');

# %% [markdown]
# The p-value is very less than the significance level of 0.05 and hence we can reject the null hypothesis and take that the series is stationary.
